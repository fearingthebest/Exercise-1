# %%
ice_cream_rating = 8
sleeping_rating = 9

# %%
first_name = input()
last_name = input()
my_name = first_name + " " + last_name
# Out:
#  Juan
#  Giraldo

# %%
happiness_rating = ((ice_cream_rating + sleeping_rating)/2)
print(happiness_rating)
# Out:
# 8.5

# %% [markdown]
# print(type(ice_cream_rating))

# %%
print("My name is " + first_name + " and I give eating ice cream a score of " + str(ice_cream_rating) + " out of 10!")
print("I am " + my_name + " and my sleeping enjoyment rating is " + str(sleeping_rating) + " / 10!")
print("Based on the factors above, my happiness rating is " + str(happiness_rating) + " out of 10, or " + str(85.0) + " %!")
# Out:
# My name is Juan and I give eating ice cream a score of 8 out of 10!
# I am Juan Giraldo and my sleeping enjoyment rating is 9 / 10!
# Based on the factors above, my happiness rating is 8.5 out of 10, or 85.0 %!
